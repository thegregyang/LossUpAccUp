# %%
# this notebook adapts https://github.com/BIGBALLON/CIFAR-ZOO
import time
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from easydict import EasyDict as edict
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
args = edict()
args.batch_size = 64
args.log_interval = 100
args.data_dir = './data'
args.lr = 0.03
args.momentum = 0.9
args.epochs = 50
args.lr_drop_epoch = 30
args.seed = 1
args.no_shuffle = False
print(args)
# Out:
# {'batch_size': 64, 'log_interval': 100, 'data_dir': './data', 'lr': 0.03, 'momentum': 0.9, 'epochs': 50, 'lr_drop_epoch': 30, 'seed': 1, 'no_shuffle': False}

# %%
# fix all seeds for reproducibility
seed = args.seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
def _init_fn(worker_id):
    np.random.seed(int(seed))

# %%
use_cuda = True
batch_size = args.batch_size
test_batch_size = args.batch_size

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = datasets.CIFAR10(root=args.data_dir, train=True,
                                        download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=not args.no_shuffle, **kwargs)

testset = datasets.CIFAR10(root=args.data_dir, train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=test_batch_size,
                                         shuffle=False, **kwargs)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified

# %%
def train(args, model, device, train_loader, optimizer, epoch,
          scheduler=None):
    model.train()
    train_loss = 0
    correct = 0
    start_time = time.time()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        train_loss += loss.item() * data.shape[0]  # sum up batch loss
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            elapsed = time.time() - start_time
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} | ms/batch {:5.2f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(),
                elapsed * 1000 / args.log_interval))
            start_time = time.time()
        if scheduler is not None:
            scheduler.step()
    train_loss /= len(train_loader.dataset)
    train_acc = correct / len(train_loader.dataset)
    print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        train_loss, correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))
    return train_loss, train_acc

# %%
def test(args, model, device, test_loader,
         evalmode=True):
    if evalmode:
        model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)

# %%
class LeNet(nn.Module):
    def __init__(self, num_classes=10):
        super(LeNet, self).__init__()
        w = 16
        self.conv_1 = nn.Conv2d(3, 6 * w, 5)
        self.bn_1 = nn.BatchNorm2d(6 * w)
        self.conv_2 = nn.Conv2d(6 * w, 16 * w, 5)
        self.bn_2 = nn.BatchNorm2d(16 * w)
        self.fc_1 = nn.Linear(16 * 5 * 5 * w, 120 * w)
        self.bn_fc1 = nn.BatchNorm1d(120 * w)
        self.fc_2 = nn.Linear(120 * w, 84 * w)
        self.bn_fc2 = nn.BatchNorm1d(84 * w)
        self.fc_3 = nn.Linear(84 * w, num_classes)
        self.out_ln = nn.LayerNorm(num_classes, elementwise_affine =False)

    def forward(self, x):
        out = F.relu(self.conv_1(x))
        out = self.bn_1(out)
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv_2(out))
        out = self.bn_2(out)
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc_1(out))
        out = self.bn_fc1(out)
        out = F.relu(self.fc_2(out))
        out = self.bn_fc2(out)
        out = self.fc_3(out)
        out = self.out_ln(out)
        return out

class LinearModel(nn.Module):
    def __init__(self, num_classes=10):
        super().__init__()
        self.lin = nn.Linear(3 * 1024, num_classes)
    def forward(self, x):
        x = x.view(-1, 3 * 1024)
        return self.lin(x)

# %%
net = LeNet().to(device)
optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=args.momentum)
scheduler = optim.lr_scheduler.StepLR(optimizer, args.lr_drop_epoch)
logs = []

# %%
for epoch in range(1, args.epochs+1):
    epoch_start_time = time.time()
    train_loss, train_acc, = train(args, net, device, train_loader, optimizer, epoch)
    test_loss, test_acc = test(args, net, device, test_loader)
    logs.append(dict(
        epoch=epoch,
        train_loss=train_loss,
        train_acc=train_acc,
        valid_loss=test_loss,
        valid_acc=test_acc
    ))
    scheduler.step()
    print('epoch time: {:5.2f}s'.format(time.time() - epoch_start_time))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.873882 | ms/batch  4.33
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 1.607184 | ms/batch 17.40
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.515400 | ms/batch 17.61
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 1.478027 | ms/batch 17.42
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.459535 | ms/batch 16.99
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 1.196419 | ms/batch 17.30
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.218459 | ms/batch 16.95
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 1.186644 | ms/batch 17.59
#
# Train set: Average loss: 1.3347, Accuracy: 27982/50000 (56%)
#
#
# Test set: Average loss: 1.1014, Accuracy: 6590/10000 (66%)
#
# epoch time: 15.94s
# Train Epoch: 2 [0/50000 (0%)]	Loss: 0.943249 | ms/batch  1.10
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 0.974293 | ms/batch 17.31
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.011122 | ms/batch 17.31
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 0.949685 | ms/batch 17.33
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.008860 | ms/batch 17.98
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 0.736291 | ms/batch 17.29
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 0.935618 | ms/batch 17.32
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 0.914390 | ms/batch 17.26
#
# Train set: Average loss: 1.0011, Accuracy: 35251/50000 (71%)
#
#
# Test set: Average loss: 1.0114, Accuracy: 7005/10000 (70%)
#
# epoch time: 15.67s
# Train Epoch: 3 [0/50000 (0%)]	Loss: 0.755861 | ms/batch  1.14
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 0.714633 | ms/batch 17.42
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 0.938150 | ms/batch 17.43
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 0.838579 | ms/batch 17.13
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 0.875301 | ms/batch 17.36
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 0.756219 | ms/batch 17.25
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.758840 | ms/batch 16.88
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 0.807898 | ms/batch 17.09
#
# Train set: Average loss: 0.8562, Accuracy: 38445/50000 (77%)
#
#
# Test set: Average loss: 0.9681, Accuracy: 7146/10000 (71%)
#
# epoch time: 15.48s
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.721228 | ms/batch  1.00
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 0.674241 | ms/batch 17.15
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 0.846563 | ms/batch 16.98
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 0.839762 | ms/batch 17.15
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 0.774151 | ms/batch 16.99
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 0.830178 | ms/batch 17.04
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 0.622530 | ms/batch 16.91
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 0.824573 | ms/batch 17.03
#
# Train set: Average loss: 0.7507, Accuracy: 40779/50000 (82%)
#
#
# Test set: Average loss: 0.9017, Accuracy: 7491/10000 (75%)
#
# epoch time: 15.32s
# Train Epoch: 5 [0/50000 (0%)]	Loss: 0.708523 | ms/batch  1.07
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 0.607872 | ms/batch 16.98
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.696842 | ms/batch 17.11
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 0.764784 | ms/batch 16.74
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.607872 | ms/batch 16.77
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 0.795139 | ms/batch 16.95
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.765603 | ms/batch 16.99
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 0.802364 | ms/batch 17.05
#
# Train set: Average loss: 0.7040, Accuracy: 41809/50000 (84%)
#
#
# Test set: Average loss: 0.9180, Accuracy: 7453/10000 (75%)
#
# epoch time: 15.30s
# Train Epoch: 6 [0/50000 (0%)]	Loss: 0.598068 | ms/batch  1.13
# Train Epoch: 6 [6400/50000 (13%)]	Loss: 0.607573 | ms/batch 16.96
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 0.682725 | ms/batch 17.03
# Train Epoch: 6 [19200/50000 (38%)]	Loss: 0.679614 | ms/batch 17.21
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 0.646266 | ms/batch 16.81
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 0.676816 | ms/batch 16.77
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.597622 | ms/batch 16.97
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 0.905762 | ms/batch 16.99
#
# Train set: Average loss: 0.6261, Accuracy: 43663/50000 (87%)
#
#
# Test set: Average loss: 0.9260, Accuracy: 7457/10000 (75%)
#
# epoch time: 15.26s
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.499324 | ms/batch  1.09
# Train Epoch: 7 [6400/50000 (13%)]	Loss: 0.467507 | ms/batch 16.91
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.584617 | ms/batch 17.03
# Train Epoch: 7 [19200/50000 (38%)]	Loss: 0.664816 | ms/batch 16.87
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 0.664771 | ms/batch 17.18
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 0.592099 | ms/batch 16.98
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.692447 | ms/batch 16.93
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 0.439568 | ms/batch 16.64
#
# Train set: Average loss: 0.6112, Accuracy: 43813/50000 (88%)
#
#
# Test set: Average loss: 0.9497, Accuracy: 7351/10000 (74%)
#
# epoch time: 15.28s
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.458890 | ms/batch  1.09
# Train Epoch: 8 [6400/50000 (13%)]	Loss: 0.437398 | ms/batch 16.99
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.400096 | ms/batch 17.22
# Train Epoch: 8 [19200/50000 (38%)]	Loss: 0.392420 | ms/batch 17.15
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.386229 | ms/batch 17.34
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 0.462449 | ms/batch 17.14
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.428673 | ms/batch 17.00
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 0.624978 | ms/batch 16.89
#
# Train set: Average loss: 0.4770, Accuracy: 46763/50000 (94%)
#
#
# Test set: Average loss: 0.9078, Accuracy: 7555/10000 (76%)
#
# epoch time: 15.38s
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.376812 | ms/batch  1.13
# Train Epoch: 9 [6400/50000 (13%)]	Loss: 0.469760 | ms/batch 16.71
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 0.380375 | ms/batch 16.78
# Train Epoch: 9 [19200/50000 (38%)]	Loss: 0.421947 | ms/batch 17.17
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.373718 | ms/batch 16.45
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 0.421773 | ms/batch 16.75
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.488497 | ms/batch 16.79
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 0.441414 | ms/batch 16.75
#
# Train set: Average loss: 0.4294, Accuracy: 47650/50000 (95%)
#
#
# Test set: Average loss: 0.9658, Accuracy: 7354/10000 (74%)
#
# epoch time: 15.10s
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.439759 | ms/batch  1.10
# Train Epoch: 10 [6400/50000 (13%)]	Loss: 0.406793 | ms/batch 16.59
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.404019 | ms/batch 17.12
# Train Epoch: 10 [19200/50000 (38%)]	Loss: 0.383965 | ms/batch 17.09
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.314965 | ms/batch 16.83
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 0.361142 | ms/batch 17.40
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.401892 | ms/batch 17.06
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 0.385314 | ms/batch 16.78
#
# Train set: Average loss: 0.3993, Accuracy: 48148/50000 (96%)
#
#
# Test set: Average loss: 0.9550, Accuracy: 7421/10000 (74%)
#
# epoch time: 15.26s
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.327682 | ms/batch  1.11
# Train Epoch: 11 [6400/50000 (13%)]	Loss: 0.342918 | ms/batch 16.76
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.346559 | ms/batch 16.82
# Train Epoch: 11 [19200/50000 (38%)]	Loss: 0.402767 | ms/batch 16.91
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.445204 | ms/batch 16.84
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 0.361787 | ms/batch 16.92
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.365230 | ms/batch 16.86
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 0.524604 | ms/batch 16.66
#
# Train set: Average loss: 0.4035, Accuracy: 47986/50000 (96%)
#
#
# Test set: Average loss: 0.9499, Accuracy: 7427/10000 (74%)
#
# epoch time: 15.15s
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.351912 | ms/batch  1.14
# Train Epoch: 12 [6400/50000 (13%)]	Loss: 0.399436 | ms/batch 16.71
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.357297 | ms/batch 16.81
# Train Epoch: 12 [19200/50000 (38%)]	Loss: 0.368374 | ms/batch 16.91
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.313867 | ms/batch 17.21
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 0.362807 | ms/batch 16.67
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.486163 | ms/batch 16.66
# Train Epoch: 12 [44800/50000 (90%)]	Loss: 0.398752 | ms/batch 17.09
#
# Train set: Average loss: 0.3792, Accuracy: 48456/50000 (97%)
#
#
# Test set: Average loss: 1.0463, Accuracy: 7053/10000 (71%)
#
# epoch time: 15.19s
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.388526 | ms/batch  1.08
# Train Epoch: 13 [6400/50000 (13%)]	Loss: 0.370635 | ms/batch 16.92
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.357123 | ms/batch 16.89
# Train Epoch: 13 [19200/50000 (38%)]	Loss: 0.455347 | ms/batch 16.93
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.506991 | ms/batch 17.10
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 0.367489 | ms/batch 17.16
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.449776 | ms/batch 16.76
# Train Epoch: 13 [44800/50000 (90%)]	Loss: 0.581813 | ms/batch 16.96
#
# Train set: Average loss: 0.4308, Accuracy: 47372/50000 (95%)
#
#
# Test set: Average loss: 1.0442, Accuracy: 7039/10000 (70%)
#
# epoch time: 15.18s
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.379273 | ms/batch  1.14
# Train Epoch: 14 [6400/50000 (13%)]	Loss: 0.431783 | ms/batch 16.70
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.428629 | ms/batch 16.63
# Train Epoch: 14 [19200/50000 (38%)]	Loss: 0.337881 | ms/batch 16.54
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.423220 | ms/batch 17.28
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 0.435191 | ms/batch 17.00
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.514039 | ms/batch 16.65
# Train Epoch: 14 [44800/50000 (90%)]	Loss: 0.340590 | ms/batch 16.92
#
# Train set: Average loss: 0.4196, Accuracy: 47586/50000 (95%)
#
#
# Test set: Average loss: 0.9813, Accuracy: 7278/10000 (73%)
#
# epoch time: 15.12s
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.401755 | ms/batch  1.14
# Train Epoch: 15 [6400/50000 (13%)]	Loss: 0.332529 | ms/batch 16.77
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.367309 | ms/batch 16.48
# Train Epoch: 15 [19200/50000 (38%)]	Loss: 0.310529 | ms/batch 17.02
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.346995 | ms/batch 16.83
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 0.354397 | ms/batch 16.74
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.326458 | ms/batch 16.99
# Train Epoch: 15 [44800/50000 (90%)]	Loss: 0.324586 | ms/batch 16.72
#
# Train set: Average loss: 0.3787, Accuracy: 48402/50000 (97%)
#
#
# Test set: Average loss: 0.9464, Accuracy: 7462/10000 (75%)
#
# epoch time: 15.12s
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.365072 | ms/batch  1.09
# Train Epoch: 16 [6400/50000 (13%)]	Loss: 0.331215 | ms/batch 16.76
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.337399 | ms/batch 16.87
# Train Epoch: 16 [19200/50000 (38%)]	Loss: 0.352835 | ms/batch 16.92
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.348641 | ms/batch 16.74
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 0.343715 | ms/batch 16.95
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.440561 | ms/batch 17.10
# Train Epoch: 16 [44800/50000 (90%)]	Loss: 0.352801 | ms/batch 16.75
#
# Train set: Average loss: 0.3594, Accuracy: 48796/50000 (98%)
#
#
# Test set: Average loss: 0.9379, Accuracy: 7522/10000 (75%)
#
# epoch time: 15.17s
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.290533 | ms/batch  1.10
# Train Epoch: 17 [6400/50000 (13%)]	Loss: 0.301337 | ms/batch 16.63
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.345179 | ms/batch 16.62
# Train Epoch: 17 [19200/50000 (38%)]	Loss: 0.362572 | ms/batch 16.76
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.297118 | ms/batch 16.74
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 0.294541 | ms/batch 16.72
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.339786 | ms/batch 16.56
# Train Epoch: 17 [44800/50000 (90%)]	Loss: 0.363786 | ms/batch 16.77
#
# Train set: Average loss: 0.3346, Accuracy: 49245/50000 (98%)
#
#
# Test set: Average loss: 0.9916, Accuracy: 7301/10000 (73%)
#
# epoch time: 15.05s
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.329858 | ms/batch  1.07
# Train Epoch: 18 [6400/50000 (13%)]	Loss: 0.303869 | ms/batch 16.55
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.365369 | ms/batch 16.88
# Train Epoch: 18 [19200/50000 (38%)]	Loss: 0.311695 | ms/batch 16.66
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.302498 | ms/batch 16.84
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 0.385654 | ms/batch 16.87
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.311575 | ms/batch 17.38
# Train Epoch: 18 [44800/50000 (90%)]	Loss: 0.382213 | ms/batch 16.93
#
# Train set: Average loss: 0.3494, Accuracy: 48972/50000 (98%)
#
#
# Test set: Average loss: 0.9592, Accuracy: 7462/10000 (75%)
#
# epoch time: 15.21s
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.303284 | ms/batch  1.06
# Train Epoch: 19 [6400/50000 (13%)]	Loss: 0.292316 | ms/batch 16.75
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.320012 | ms/batch 16.66
# Train Epoch: 19 [19200/50000 (38%)]	Loss: 0.364923 | ms/batch 16.86
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.335665 | ms/batch 16.82
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 0.322531 | ms/batch 16.64
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.309722 | ms/batch 16.81
# Train Epoch: 19 [44800/50000 (90%)]	Loss: 0.328611 | ms/batch 16.55
#
# Train set: Average loss: 0.3356, Accuracy: 49205/50000 (98%)
#
#
# Test set: Average loss: 0.9560, Accuracy: 7444/10000 (74%)
#
# epoch time: 15.05s
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.305686 | ms/batch  1.05
# Train Epoch: 20 [6400/50000 (13%)]	Loss: 0.313074 | ms/batch 16.99
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.342953 | ms/batch 16.73
# Train Epoch: 20 [19200/50000 (38%)]	Loss: 0.323602 | ms/batch 16.68
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.346356 | ms/batch 17.35
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 0.307348 | ms/batch 16.65
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.303232 | ms/batch 17.13
# Train Epoch: 20 [44800/50000 (90%)]	Loss: 0.292530 | ms/batch 16.76
#
# Train set: Average loss: 0.3127, Accuracy: 49645/50000 (99%)
#
#
# Test set: Average loss: 0.9481, Accuracy: 7502/10000 (75%)
#
# epoch time: 15.25s
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.292377 | ms/batch  1.13
# Train Epoch: 21 [6400/50000 (13%)]	Loss: 0.287387 | ms/batch 16.63
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.304727 | ms/batch 16.55
# Train Epoch: 21 [19200/50000 (38%)]	Loss: 0.331839 | ms/batch 16.47
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.301804 | ms/batch 16.71
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 0.362572 | ms/batch 16.57
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.324059 | ms/batch 16.68
# Train Epoch: 21 [44800/50000 (90%)]	Loss: 0.314913 | ms/batch 16.59
#
# Train set: Average loss: 0.3139, Accuracy: 49581/50000 (99%)
#
#
# Test set: Average loss: 0.9595, Accuracy: 7484/10000 (75%)
#
# epoch time: 14.98s
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.289991 | ms/batch  1.09
# Train Epoch: 22 [6400/50000 (13%)]	Loss: 0.347452 | ms/batch 16.72
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.304548 | ms/batch 17.18
# Train Epoch: 22 [19200/50000 (38%)]	Loss: 0.297418 | ms/batch 17.02
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.290775 | ms/batch 16.89
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 0.290481 | ms/batch 17.02
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.302660 | ms/batch 16.43
# Train Epoch: 22 [44800/50000 (90%)]	Loss: 0.309103 | ms/batch 16.85
#
# Train set: Average loss: 0.3039, Accuracy: 49754/50000 (100%)
#
#
# Test set: Average loss: 0.9327, Accuracy: 7597/10000 (76%)
#
# epoch time: 15.11s
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.282263 | ms/batch  1.06
# Train Epoch: 23 [6400/50000 (13%)]	Loss: 0.307357 | ms/batch 16.67
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.290842 | ms/batch 16.78
# Train Epoch: 23 [19200/50000 (38%)]	Loss: 0.290313 | ms/batch 16.76
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.287187 | ms/batch 16.79
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 0.285746 | ms/batch 17.08
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.286131 | ms/batch 17.43
# Train Epoch: 23 [44800/50000 (90%)]	Loss: 0.297259 | ms/batch 16.96
#
# Train set: Average loss: 0.2981, Accuracy: 49825/50000 (100%)
#
#
# Test set: Average loss: 0.9336, Accuracy: 7576/10000 (76%)
#
# epoch time: 15.27s
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.331653 | ms/batch  1.13
# Train Epoch: 24 [6400/50000 (13%)]	Loss: 0.285362 | ms/batch 16.80
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.309500 | ms/batch 17.19
# Train Epoch: 24 [19200/50000 (38%)]	Loss: 0.300143 | ms/batch 16.84
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.294938 | ms/batch 17.24
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 0.284125 | ms/batch 16.65
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.286903 | ms/batch 16.91
# Train Epoch: 24 [44800/50000 (90%)]	Loss: 0.293707 | ms/batch 16.92
#
# Train set: Average loss: 0.2957, Accuracy: 49867/50000 (100%)
#
#
# Test set: Average loss: 0.9424, Accuracy: 7532/10000 (75%)
#
# epoch time: 15.40s
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.285258 | ms/batch  1.16
# Train Epoch: 25 [6400/50000 (13%)]	Loss: 0.283334 | ms/batch 18.77
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.289854 | ms/batch 17.54
# Train Epoch: 25 [19200/50000 (38%)]	Loss: 0.285680 | ms/batch 17.29
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.289608 | ms/batch 16.88
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 0.285342 | ms/batch 18.06
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.295510 | ms/batch 17.88
# Train Epoch: 25 [44800/50000 (90%)]	Loss: 0.294823 | ms/batch 18.26
#
# Train set: Average loss: 0.2932, Accuracy: 49890/50000 (100%)
#
#
# Test set: Average loss: 0.9363, Accuracy: 7556/10000 (76%)
#
# epoch time: 16.01s
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.290887 | ms/batch  1.21
# Train Epoch: 26 [6400/50000 (13%)]	Loss: 0.288235 | ms/batch 17.05
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.286232 | ms/batch 17.06
# Train Epoch: 26 [19200/50000 (38%)]	Loss: 0.283798 | ms/batch 17.63
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.304468 | ms/batch 18.08
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 0.286353 | ms/batch 17.43
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.294413 | ms/batch 17.77
# Train Epoch: 26 [44800/50000 (90%)]	Loss: 0.289570 | ms/batch 17.96
#
# Train set: Average loss: 0.2923, Accuracy: 49922/50000 (100%)
#
#
# Test set: Average loss: 0.9361, Accuracy: 7594/10000 (76%)
#
# epoch time: 15.96s
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.286061 | ms/batch  1.18
# Train Epoch: 27 [6400/50000 (13%)]	Loss: 0.284188 | ms/batch 17.46
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.284836 | ms/batch 17.69
# Train Epoch: 27 [19200/50000 (38%)]	Loss: 0.284443 | ms/batch 17.56
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.286266 | ms/batch 18.05
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 0.293962 | ms/batch 18.16
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.284505 | ms/batch 17.57
# Train Epoch: 27 [44800/50000 (90%)]	Loss: 0.287604 | ms/batch 17.91
#
# Train set: Average loss: 0.2899, Accuracy: 49949/50000 (100%)
#
#
# Test set: Average loss: 0.9295, Accuracy: 7605/10000 (76%)
#
# epoch time: 16.03s
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.291032 | ms/batch  1.22
# Train Epoch: 28 [6400/50000 (13%)]	Loss: 0.286337 | ms/batch 17.70
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.289269 | ms/batch 18.04
# Train Epoch: 28 [19200/50000 (38%)]	Loss: 0.289600 | ms/batch 17.73
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.293837 | ms/batch 18.01
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 0.291304 | ms/batch 17.63
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.287652 | ms/batch 17.51
# Train Epoch: 28 [44800/50000 (90%)]	Loss: 0.287596 | ms/batch 17.55
#
# Train set: Average loss: 0.2891, Accuracy: 49952/50000 (100%)
#
#
# Test set: Average loss: 0.9454, Accuracy: 7555/10000 (76%)
#
# epoch time: 15.99s
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.303515 | ms/batch  1.17
# Train Epoch: 29 [6400/50000 (13%)]	Loss: 0.282035 | ms/batch 17.53
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.284570 | ms/batch 17.41
# Train Epoch: 29 [19200/50000 (38%)]	Loss: 0.285725 | ms/batch 17.68
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.289444 | ms/batch 17.46
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 0.286971 | ms/batch 17.15
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.285400 | ms/batch 17.23
# Train Epoch: 29 [44800/50000 (90%)]	Loss: 0.285385 | ms/batch 17.35
#
# Train set: Average loss: 0.2895, Accuracy: 49938/50000 (100%)
#
#
# Test set: Average loss: 0.9542, Accuracy: 7501/10000 (75%)
#
# epoch time: 15.82s
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.290370 | ms/batch  1.14
# Train Epoch: 30 [6400/50000 (13%)]	Loss: 0.285616 | ms/batch 18.11
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.289140 | ms/batch 17.82
# Train Epoch: 30 [19200/50000 (38%)]	Loss: 0.367192 | ms/batch 19.03
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.309305 | ms/batch 19.58
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 0.294394 | ms/batch 19.24
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.294435 | ms/batch 18.13
# Train Epoch: 30 [44800/50000 (90%)]	Loss: 0.320755 | ms/batch 18.26
#
# Train set: Average loss: 0.3033, Accuracy: 49726/50000 (99%)
#
#
# Test set: Average loss: 0.9558, Accuracy: 7474/10000 (75%)
#
# epoch time: 16.72s
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.282136 | ms/batch  1.18
# Train Epoch: 31 [6400/50000 (13%)]	Loss: 0.294907 | ms/batch 17.51
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.292132 | ms/batch 17.43
# Train Epoch: 31 [19200/50000 (38%)]	Loss: 0.292394 | ms/batch 17.72
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.286999 | ms/batch 17.61
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 0.297390 | ms/batch 17.08
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.289915 | ms/batch 17.10
# Train Epoch: 31 [44800/50000 (90%)]	Loss: 0.283092 | ms/batch 17.30
#
# Train set: Average loss: 0.2920, Accuracy: 49920/50000 (100%)
#
#
# Test set: Average loss: 0.9348, Accuracy: 7576/10000 (76%)
#
# epoch time: 15.62s
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.285799 | ms/batch  1.11
# Train Epoch: 32 [6400/50000 (13%)]	Loss: 0.298203 | ms/batch 17.21
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.287799 | ms/batch 17.11
# Train Epoch: 32 [19200/50000 (38%)]	Loss: 0.288673 | ms/batch 17.20
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.286612 | ms/batch 17.08
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 0.287514 | ms/batch 17.13
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.282783 | ms/batch 17.32
# Train Epoch: 32 [44800/50000 (90%)]	Loss: 0.283740 | ms/batch 17.77
#
# Train set: Average loss: 0.2896, Accuracy: 49952/50000 (100%)
#
#
# Test set: Average loss: 0.9339, Accuracy: 7539/10000 (75%)
#
# epoch time: 15.58s
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.287805 | ms/batch  1.08
# Train Epoch: 33 [6400/50000 (13%)]	Loss: 0.292295 | ms/batch 17.13
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.285384 | ms/batch 17.16
# Train Epoch: 33 [19200/50000 (38%)]	Loss: 0.283087 | ms/batch 17.09
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.301029 | ms/batch 17.28
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 0.284924 | ms/batch 16.85
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.284809 | ms/batch 17.00
# Train Epoch: 33 [44800/50000 (90%)]	Loss: 0.287523 | ms/batch 16.98
#
# Train set: Average loss: 0.2893, Accuracy: 49946/50000 (100%)
#
#
# Test set: Average loss: 0.9345, Accuracy: 7587/10000 (76%)
#
# epoch time: 15.44s
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.285934 | ms/batch  1.23
# Train Epoch: 34 [6400/50000 (13%)]	Loss: 0.283898 | ms/batch 17.54
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.287735 | ms/batch 17.28
# Train Epoch: 34 [19200/50000 (38%)]	Loss: 0.285584 | ms/batch 17.03
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.283321 | ms/batch 17.08
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 0.314813 | ms/batch 17.31
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.289498 | ms/batch 16.90
# Train Epoch: 34 [44800/50000 (90%)]	Loss: 0.285101 | ms/batch 17.18
#
# Train set: Average loss: 0.2877, Accuracy: 49977/50000 (100%)
#
#
# Test set: Average loss: 0.9338, Accuracy: 7557/10000 (76%)
#
# epoch time: 15.44s
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.285649 | ms/batch  1.14
# Train Epoch: 35 [6400/50000 (13%)]	Loss: 0.284880 | ms/batch 16.72
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.284925 | ms/batch 16.97
# Train Epoch: 35 [19200/50000 (38%)]	Loss: 0.286132 | ms/batch 16.86
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.291191 | ms/batch 17.80
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 0.282919 | ms/batch 16.96
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.288725 | ms/batch 16.88
# Train Epoch: 35 [44800/50000 (90%)]	Loss: 0.282939 | ms/batch 16.90
#
# Train set: Average loss: 0.2879, Accuracy: 49973/50000 (100%)
#
#
# Test set: Average loss: 0.9362, Accuracy: 7555/10000 (76%)
#
# epoch time: 15.32s
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.283803 | ms/batch  1.14
# Train Epoch: 36 [6400/50000 (13%)]	Loss: 0.288995 | ms/batch 17.05
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.285856 | ms/batch 17.02
# Train Epoch: 36 [19200/50000 (38%)]	Loss: 0.283136 | ms/batch 17.14
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.284794 | ms/batch 17.16
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 0.286698 | ms/batch 17.03
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.290932 | ms/batch 17.10
# Train Epoch: 36 [44800/50000 (90%)]	Loss: 0.290630 | ms/batch 17.19
#
# Train set: Average loss: 0.2874, Accuracy: 49970/50000 (100%)
#
#
# Test set: Average loss: 0.9344, Accuracy: 7569/10000 (76%)
#
# epoch time: 15.42s
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.294340 | ms/batch  1.16
# Train Epoch: 37 [6400/50000 (13%)]	Loss: 0.283822 | ms/batch 17.06
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.287601 | ms/batch 16.87
# Train Epoch: 37 [19200/50000 (38%)]	Loss: 0.284918 | ms/batch 16.89
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.286367 | ms/batch 17.02
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 0.313981 | ms/batch 17.03
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.284396 | ms/batch 16.91
# Train Epoch: 37 [44800/50000 (90%)]	Loss: 0.298904 | ms/batch 16.61
#
# Train set: Average loss: 0.2875, Accuracy: 49971/50000 (100%)
#
#
# Test set: Average loss: 0.9295, Accuracy: 7580/10000 (76%)
#
# epoch time: 15.25s
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.292936 | ms/batch  1.12
# Train Epoch: 38 [6400/50000 (13%)]	Loss: 0.284049 | ms/batch 17.11
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.282134 | ms/batch 16.96
# Train Epoch: 38 [19200/50000 (38%)]	Loss: 0.291633 | ms/batch 17.06
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.284844 | ms/batch 17.22
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 0.286464 | ms/batch 17.20
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.302281 | ms/batch 16.80
# Train Epoch: 38 [44800/50000 (90%)]	Loss: 0.305671 | ms/batch 16.98
#
# Train set: Average loss: 0.2873, Accuracy: 49969/50000 (100%)
#
#
# Test set: Average loss: 0.9279, Accuracy: 7607/10000 (76%)
#
# epoch time: 15.41s
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.284728 | ms/batch  1.06
# Train Epoch: 39 [6400/50000 (13%)]	Loss: 0.302404 | ms/batch 16.95
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.285180 | ms/batch 17.15
# Train Epoch: 39 [19200/50000 (38%)]	Loss: 0.284808 | ms/batch 17.01
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.289447 | ms/batch 17.17
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 0.281384 | ms/batch 17.18
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.283026 | ms/batch 17.03
# Train Epoch: 39 [44800/50000 (90%)]	Loss: 0.289987 | ms/batch 17.17
#
# Train set: Average loss: 0.2870, Accuracy: 49973/50000 (100%)
#
#
# Test set: Average loss: 0.9348, Accuracy: 7575/10000 (76%)
#
# epoch time: 15.41s
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.289207 | ms/batch  1.04
# Train Epoch: 40 [6400/50000 (13%)]	Loss: 0.286098 | ms/batch 17.06
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.285627 | ms/batch 17.04
# Train Epoch: 40 [19200/50000 (38%)]	Loss: 0.285132 | ms/batch 17.57
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.281952 | ms/batch 17.08
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 0.283463 | ms/batch 17.33
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.284598 | ms/batch 17.34
# Train Epoch: 40 [44800/50000 (90%)]	Loss: 0.308833 | ms/batch 17.10
#
# Train set: Average loss: 0.2869, Accuracy: 49973/50000 (100%)
#
#
# Test set: Average loss: 0.9390, Accuracy: 7574/10000 (76%)
#
# epoch time: 15.53s
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.283535 | ms/batch  1.10
# Train Epoch: 41 [6400/50000 (13%)]	Loss: 0.288306 | ms/batch 16.60
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.288379 | ms/batch 17.13
# Train Epoch: 41 [19200/50000 (38%)]	Loss: 0.285355 | ms/batch 16.88
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.283079 | ms/batch 16.81
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 0.288292 | ms/batch 16.95
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.309999 | ms/batch 16.82
# Train Epoch: 41 [44800/50000 (90%)]	Loss: 0.284595 | ms/batch 17.22
#
# Train set: Average loss: 0.2863, Accuracy: 49982/50000 (100%)
#
#
# Test set: Average loss: 0.9322, Accuracy: 7588/10000 (76%)
#
# epoch time: 15.29s
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.285916 | ms/batch  1.19
# Train Epoch: 42 [6400/50000 (13%)]	Loss: 0.282584 | ms/batch 16.98
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.295657 | ms/batch 17.05
# Train Epoch: 42 [19200/50000 (38%)]	Loss: 0.284150 | ms/batch 17.23
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.282599 | ms/batch 16.73
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 0.284453 | ms/batch 16.87
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.285308 | ms/batch 16.88
# Train Epoch: 42 [44800/50000 (90%)]	Loss: 0.283984 | ms/batch 17.01
#
# Train set: Average loss: 0.2863, Accuracy: 49976/50000 (100%)
#
#
# Test set: Average loss: 0.9325, Accuracy: 7576/10000 (76%)
#
# epoch time: 15.28s
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.282059 | ms/batch  1.23
# Train Epoch: 43 [6400/50000 (13%)]	Loss: 0.281886 | ms/batch 16.63
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.284531 | ms/batch 16.77
# Train Epoch: 43 [19200/50000 (38%)]	Loss: 0.288319 | ms/batch 16.92
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.290486 | ms/batch 16.91
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 0.288675 | ms/batch 16.92
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.293465 | ms/batch 17.10
# Train Epoch: 43 [44800/50000 (90%)]	Loss: 0.283173 | ms/batch 17.14
#
# Train set: Average loss: 0.2862, Accuracy: 49984/50000 (100%)
#
#
# Test set: Average loss: 0.9339, Accuracy: 7605/10000 (76%)
#
# epoch time: 15.25s
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.282970 | ms/batch  1.10
# Train Epoch: 44 [6400/50000 (13%)]	Loss: 0.281858 | ms/batch 16.98
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.286814 | ms/batch 16.92
# Train Epoch: 44 [19200/50000 (38%)]	Loss: 0.281856 | ms/batch 17.15
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.282582 | ms/batch 17.22
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 0.284515 | ms/batch 17.42
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.283529 | ms/batch 16.96
# Train Epoch: 44 [44800/50000 (90%)]	Loss: 0.285912 | ms/batch 17.32
#
# Train set: Average loss: 0.2862, Accuracy: 49980/50000 (100%)
#
#
# Test set: Average loss: 0.9287, Accuracy: 7606/10000 (76%)
#
# epoch time: 15.45s
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.289851 | ms/batch  1.18
# Train Epoch: 45 [6400/50000 (13%)]	Loss: 0.284131 | ms/batch 17.35
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.282421 | ms/batch 17.05
# Train Epoch: 45 [19200/50000 (38%)]	Loss: 0.285197 | ms/batch 16.87
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.282336 | ms/batch 16.77
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 0.282178 | ms/batch 16.78
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.286394 | ms/batch 17.00
# Train Epoch: 45 [44800/50000 (90%)]	Loss: 0.285017 | ms/batch 16.70
#
# Train set: Average loss: 0.2860, Accuracy: 49984/50000 (100%)
#
#
# Test set: Average loss: 0.9350, Accuracy: 7593/10000 (76%)
#
# epoch time: 15.26s
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.288004 | ms/batch  1.13
# Train Epoch: 46 [6400/50000 (13%)]	Loss: 0.282049 | ms/batch 16.83
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.285192 | ms/batch 16.88
# Train Epoch: 46 [19200/50000 (38%)]	Loss: 0.285075 | ms/batch 16.83
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.282469 | ms/batch 16.99
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 0.282759 | ms/batch 17.30
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.283864 | ms/batch 16.89
# Train Epoch: 46 [44800/50000 (90%)]	Loss: 0.285682 | ms/batch 17.12
#
# Train set: Average loss: 0.2854, Accuracy: 49983/50000 (100%)
#
#
# Test set: Average loss: 0.9332, Accuracy: 7593/10000 (76%)
#
# epoch time: 15.26s
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.283443 | ms/batch  1.12
# Train Epoch: 47 [6400/50000 (13%)]	Loss: 0.283781 | ms/batch 17.32
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.288656 | ms/batch 17.27
# Train Epoch: 47 [19200/50000 (38%)]	Loss: 0.283569 | ms/batch 17.00
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.285037 | ms/batch 16.87
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 0.280936 | ms/batch 16.93
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.283871 | ms/batch 16.69
# Train Epoch: 47 [44800/50000 (90%)]	Loss: 0.282703 | ms/batch 17.05
#
# Train set: Average loss: 0.2856, Accuracy: 49987/50000 (100%)
#
#
# Test set: Average loss: 0.9285, Accuracy: 7623/10000 (76%)
#
# epoch time: 15.34s
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.283049 | ms/batch  1.11
# Train Epoch: 48 [6400/50000 (13%)]	Loss: 0.288283 | ms/batch 17.06
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.293563 | ms/batch 16.98
# Train Epoch: 48 [19200/50000 (38%)]	Loss: 0.285997 | ms/batch 16.76
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.287095 | ms/batch 16.86
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 0.288474 | ms/batch 17.06
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.290176 | ms/batch 16.62
# Train Epoch: 48 [44800/50000 (90%)]	Loss: 0.295270 | ms/batch 17.02
#
# Train set: Average loss: 0.2852, Accuracy: 49990/50000 (100%)
#
#
# Test set: Average loss: 0.9254, Accuracy: 7633/10000 (76%)
#
# epoch time: 15.26s
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.290928 | ms/batch  1.16
# Train Epoch: 49 [6400/50000 (13%)]	Loss: 0.287298 | ms/batch 16.78
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.281778 | ms/batch 17.06
# Train Epoch: 49 [19200/50000 (38%)]	Loss: 0.284754 | ms/batch 17.16
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.283893 | ms/batch 16.98
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 0.286277 | ms/batch 16.86
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.283830 | ms/batch 16.56
# Train Epoch: 49 [44800/50000 (90%)]	Loss: 0.301599 | ms/batch 17.34
#
# Train set: Average loss: 0.2856, Accuracy: 49985/50000 (100%)
#
#
# Test set: Average loss: 0.9259, Accuracy: 7611/10000 (76%)
#
# epoch time: 15.35s
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.280910 | ms/batch  1.09
# Train Epoch: 50 [6400/50000 (13%)]	Loss: 0.282679 | ms/batch 17.09
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.282492 | ms/batch 16.84
# Train Epoch: 50 [19200/50000 (38%)]	Loss: 0.283994 | ms/batch 16.77
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.285661 | ms/batch 16.89
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 0.281532 | ms/batch 16.90
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.288993 | ms/batch 16.97
# Train Epoch: 50 [44800/50000 (90%)]	Loss: 0.286013 | ms/batch 16.73
#
# Train set: Average loss: 0.2853, Accuracy: 49987/50000 (100%)
#
#
# Test set: Average loss: 0.9301, Accuracy: 7613/10000 (76%)
#
# epoch time: 15.20s

# %%
logdf = pd.DataFrame(logs)

# %%
best_loss_epoch, best_loss = logdf.sort_values(by='valid_loss')[['epoch', 'valid_loss']].to_numpy()[0]
best_acc_epoch, best_acc = logdf.sort_values(by='valid_acc', ascending=False)[['epoch', 'valid_acc']].to_numpy()[0]
print(f'Best validation loss is {best_loss:.4f}, achieved at epoch {int(best_loss_epoch)}.\n'
      f'But best validation accuracy is {best_acc}, achieved much later at epoch {int(best_acc_epoch)}.')
# Out:
# Best validation loss is 0.9017, achieved at epoch 4.
# But best validation accuracy is 0.7633, achieved much later at epoch 48.

# %%
def tight_layout(fig):
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
plt.figure(figsize=(8, 4))
plt.subplot(121)
sns.lineplot(data=logdf, x='epoch', y='valid_loss')
plt.axvline(best_loss_epoch, c='orange')
plt.annotate(f'validation loss\nincreases after\nepoch {int(best_loss_epoch)},\nindicating\n"overfitting"',
            xy=(best_loss_epoch, best_loss),  xycoords='data',
            xytext=(30, 1.05), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             wrap=True
            )
plt.subplot(122)
sns.lineplot(data=logdf, x='epoch', y='valid_acc')
plt.axvline(best_loss_epoch, c='orange')
plt.text(20, 0.68,
         f'...but\nvalidation\naccuracy\ncontinues\nto increase\nwell after\nepoch {int(best_loss_epoch)}!',
         horizontalalignment='left', verticalalignment='bottom')
plt.suptitle('LeNet loss & accuracy increase simultaneously on CIFAR10 even with normalized logits')
tight_layout(plt)
plt.savefig('lenet-normalized-logits.png', dpi=200, bbox_inches='tight')

# %%
plt.figure(figsize=(8, 4))
plt.subplot(121)
sns.lineplot(data=logdf, x='epoch', y='train_loss')
plt.axvline(best_loss_epoch, c='orange')
plt.annotate(f'validation loss\nincreases after\nepoch {int(best_loss_epoch)}',
            xy=(best_loss_epoch, best_loss),  xycoords='data',
            xytext=(15, 1.2), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             wrap=True
            )
plt.subplot(122)
sns.lineplot(data=logdf, x='epoch', y='train_acc')
plt.axvline(best_loss_epoch, c='orange')
plt.annotate(f'validation loss\nincreases after\nepoch {int(best_loss_epoch)}',
            xy=(best_loss_epoch, .8),  xycoords='data',
            xytext=(30, 0.8), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             wrap=True
            )
plt.suptitle('LeNet training loss and accuracy')
tight_layout(plt)
plt.savefig('lenet-normalized-logits-training.png', dpi=200, bbox_inches='tight')
