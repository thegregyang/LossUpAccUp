# %%
# this notebook adapts https://github.com/BIGBALLON/CIFAR-ZOO
import time
import random

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torchvision import datasets, transforms
from easydict import EasyDict as edict

# %%
args = edict()
args.batch_size = 64
args.log_interval = 100
args.data_dir = './data'
args.lr = 0.01
args.momentum = 0.9
args.epochs = 50
args.lr_drop_epoch = 20
args.seed = 1
args.no_shuffle = False
print(args)
# Out:
# {'batch_size': 64, 'log_interval': 100, 'data_dir': './data', 'lr': 0.01, 'momentum': 0.9, 'epochs': 50, 'lr_drop_epoch': 20, 'seed': 1, 'no_shuffle': False}

# %%
# fix all seeds for reproducibility
seed = args.seed
torch.manual_seed(seed)
torch.cuda.manual_seed(seed)
torch.cuda.manual_seed_all(seed)  # if you are using multi-GPU.
np.random.seed(seed)  # Numpy module.
random.seed(seed)  # Python random module.
torch.manual_seed(seed)
torch.backends.cudnn.benchmark = False
torch.backends.cudnn.deterministic = True
def _init_fn(worker_id):
    np.random.seed(int(seed))

# %%
use_cuda = True
batch_size = args.batch_size
test_batch_size = args.batch_size

device = torch.device("cuda" if use_cuda else "cpu")

kwargs = {'num_workers': 2, 'pin_memory': True} if use_cuda else {}

transform = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))])

trainset = datasets.CIFAR10(root=args.data_dir, train=True,
                                        download=True, transform=transform)
train_loader = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=not args.no_shuffle, **kwargs)

testset = datasets.CIFAR10(root=args.data_dir, train=False,
                                       download=True, transform=transform)
test_loader = torch.utils.data.DataLoader(testset, batch_size=test_batch_size,
                                         shuffle=False, **kwargs)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train(args, model, device, train_loader, optimizer, epoch,
          scheduler=None):
    model.train()
    train_loss = 0
    correct = 0
    start_time = time.time()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.cross_entropy(output, target)
        loss.backward()
        train_loss += loss.item() * data.shape[0]  # sum up batch loss
        pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
        correct += pred.eq(target.view_as(pred)).sum().item()
        optimizer.step()
        if batch_idx % args.log_interval == 0:
            elapsed = time.time() - start_time
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f} | ms/batch {:5.2f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.item(),
                elapsed * 1000 / args.log_interval))
            start_time = time.time()
        if scheduler is not None:
            scheduler.step()
    train_loss /= len(train_loader.dataset)
    train_acc = correct / len(train_loader.dataset)
    print('\nTrain set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        train_loss, correct, len(train_loader.dataset),
        100. * correct / len(train_loader.dataset)))
    return train_loss, train_acc

# %%
def test(args, model, device, test_loader,
         evalmode=True):
    if evalmode:
        model.eval()
    test_loss = 0
    correct = 0
    with torch.no_grad():
        for data, target in test_loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.cross_entropy(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()

    test_loss /= len(test_loader.dataset)

    print('\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
        test_loss, correct, len(test_loader.dataset),
        100. * correct / len(test_loader.dataset)))
    return test_loss, correct / len(test_loader.dataset)

# %%
class LeNet(nn.Module):
    def __init__(self, num_classes=10):
        super(LeNet, self).__init__()
        w = 1
        self.conv_1 = nn.Conv2d(3, 6 * w, 5)
        self.conv_2 = nn.Conv2d(6 * w, 16 * w, 5)
        self.fc_1 = nn.Linear(16 * 5 * 5 * w, 64 * w)
        self.fc_2 = nn.Linear(64 * w, num_classes)

    def forward(self, x):
        out = F.relu(self.conv_1(x))
        out = F.max_pool2d(out, 2)
        out = F.relu(self.conv_2(out))
        out = F.max_pool2d(out, 2)
        out = out.view(out.size(0), -1)
        out = F.relu(self.fc_1(out))
        out = self.fc_2(out)
        return out

# %%
net = LeNet().to(device)
optimizer = optim.SGD(net.parameters(), lr=args.lr, momentum=args.momentum)
scheduler = optim.lr_scheduler.StepLR(optimizer, args.lr_drop_epoch)
logs = []

# %%
for epoch in range(1, args.epochs+1):
    epoch_start_time = time.time()
    train_loss, train_acc, = train(args, net, device, train_loader, optimizer, epoch)
    test_loss, test_acc = test(args, net, device, test_loader)
    logs.append(dict(
        epoch=epoch,
        train_loss=train_loss,
        train_acc=train_acc,
        valid_loss=test_loss,
        valid_acc=test_acc
    ))
    scheduler.step()
    print('epoch time: {:5.2f}s'.format(time.time() - epoch_start_time))
# Out:
# Train Epoch: 1 [0/50000 (0%)]	Loss: 2.317482 | ms/batch  4.13
# Train Epoch: 1 [6400/50000 (13%)]	Loss: 2.201630 | ms/batch  7.46
# Train Epoch: 1 [12800/50000 (26%)]	Loss: 1.955650 | ms/batch  7.61
# Train Epoch: 1 [19200/50000 (38%)]	Loss: 1.795920 | ms/batch  7.72
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.645254 | ms/batch  7.84
# Train Epoch: 1 [32000/50000 (64%)]	Loss: 1.793328 | ms/batch  7.62
# Train Epoch: 1 [38400/50000 (77%)]	Loss: 1.390746 | ms/batch  8.22
# Train Epoch: 1 [44800/50000 (90%)]	Loss: 1.415353 | ms/batch  7.75
#
# Train set: Average loss: 1.7282, Accuracy: 18254/50000 (37%)
#
#
# Test set: Average loss: 1.4185, Accuracy: 4866/10000 (49%)
#
# epoch time:  7.83s
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.608499 | ms/batch  1.11
# Train Epoch: 2 [6400/50000 (13%)]	Loss: 1.372869 | ms/batch  7.42
# Train Epoch: 2 [12800/50000 (26%)]	Loss: 1.243767 | ms/batch  7.65
# Train Epoch: 2 [19200/50000 (38%)]	Loss: 1.493573 | ms/batch  7.81
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.206892 | ms/batch  8.45
# Train Epoch: 2 [32000/50000 (64%)]	Loss: 1.407069 | ms/batch  7.86
# Train Epoch: 2 [38400/50000 (77%)]	Loss: 1.174525 | ms/batch  7.56
# Train Epoch: 2 [44800/50000 (90%)]	Loss: 1.088409 | ms/batch  7.83
#
# Train set: Average loss: 1.3616, Accuracy: 25367/50000 (51%)
#
#
# Test set: Average loss: 1.2870, Accuracy: 5445/10000 (54%)
#
# epoch time:  7.47s
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.351267 | ms/batch  1.31
# Train Epoch: 3 [6400/50000 (13%)]	Loss: 1.125026 | ms/batch  7.56
# Train Epoch: 3 [12800/50000 (26%)]	Loss: 1.110846 | ms/batch  7.60
# Train Epoch: 3 [19200/50000 (38%)]	Loss: 1.324063 | ms/batch  7.39
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.199777 | ms/batch  7.25
# Train Epoch: 3 [32000/50000 (64%)]	Loss: 1.522060 | ms/batch  7.79
# Train Epoch: 3 [38400/50000 (77%)]	Loss: 0.956355 | ms/batch  8.17
# Train Epoch: 3 [44800/50000 (90%)]	Loss: 1.350014 | ms/batch  8.04
#
# Train set: Average loss: 1.2286, Accuracy: 28107/50000 (56%)
#
#
# Test set: Average loss: 1.2173, Accuracy: 5675/10000 (57%)
#
# epoch time:  7.51s
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.220387 | ms/batch  1.32
# Train Epoch: 4 [6400/50000 (13%)]	Loss: 1.058920 | ms/batch  7.81
# Train Epoch: 4 [12800/50000 (26%)]	Loss: 1.015985 | ms/batch  8.08
# Train Epoch: 4 [19200/50000 (38%)]	Loss: 0.881859 | ms/batch  7.68
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.116773 | ms/batch  8.10
# Train Epoch: 4 [32000/50000 (64%)]	Loss: 1.029010 | ms/batch  7.48
# Train Epoch: 4 [38400/50000 (77%)]	Loss: 1.097495 | ms/batch  7.66
# Train Epoch: 4 [44800/50000 (90%)]	Loss: 1.058514 | ms/batch  7.75
#
# Train set: Average loss: 1.1388, Accuracy: 29792/50000 (60%)
#
#
# Test set: Average loss: 1.1430, Accuracy: 6033/10000 (60%)
#
# epoch time:  7.57s
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.086297 | ms/batch  1.08
# Train Epoch: 5 [6400/50000 (13%)]	Loss: 0.933174 | ms/batch  8.19
# Train Epoch: 5 [12800/50000 (26%)]	Loss: 0.998615 | ms/batch  8.29
# Train Epoch: 5 [19200/50000 (38%)]	Loss: 0.751762 | ms/batch  8.10
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.324409 | ms/batch  7.71
# Train Epoch: 5 [32000/50000 (64%)]	Loss: 1.080778 | ms/batch  7.97
# Train Epoch: 5 [38400/50000 (77%)]	Loss: 0.902135 | ms/batch  7.32
# Train Epoch: 5 [44800/50000 (90%)]	Loss: 1.054582 | ms/batch  7.98
#
# Train set: Average loss: 1.0731, Accuracy: 31003/50000 (62%)
#
#
# Test set: Average loss: 1.1702, Accuracy: 5877/10000 (59%)
#
# epoch time:  7.63s
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.185809 | ms/batch  1.18
# Train Epoch: 6 [6400/50000 (13%)]	Loss: 0.996219 | ms/batch  7.54
# Train Epoch: 6 [12800/50000 (26%)]	Loss: 1.168155 | ms/batch  7.50
# Train Epoch: 6 [19200/50000 (38%)]	Loss: 1.140242 | ms/batch  8.08
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.140796 | ms/batch  8.67
# Train Epoch: 6 [32000/50000 (64%)]	Loss: 0.923521 | ms/batch  7.52
# Train Epoch: 6 [38400/50000 (77%)]	Loss: 0.868850 | ms/batch  8.21
# Train Epoch: 6 [44800/50000 (90%)]	Loss: 1.079552 | ms/batch  8.41
#
# Train set: Average loss: 1.0287, Accuracy: 31913/50000 (64%)
#
#
# Test set: Average loss: 1.1153, Accuracy: 6162/10000 (62%)
#
# epoch time:  7.67s
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.939200 | ms/batch  1.07
# Train Epoch: 7 [6400/50000 (13%)]	Loss: 0.966691 | ms/batch  7.86
# Train Epoch: 7 [12800/50000 (26%)]	Loss: 0.957334 | ms/batch  8.43
# Train Epoch: 7 [19200/50000 (38%)]	Loss: 1.036653 | ms/batch  7.97
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.022743 | ms/batch  8.13
# Train Epoch: 7 [32000/50000 (64%)]	Loss: 1.106477 | ms/batch  8.50
# Train Epoch: 7 [38400/50000 (77%)]	Loss: 0.832989 | ms/batch  9.02
# Train Epoch: 7 [44800/50000 (90%)]	Loss: 1.084068 | ms/batch  7.51
#
# Train set: Average loss: 0.9901, Accuracy: 32550/50000 (65%)
#
#
# Test set: Average loss: 1.1355, Accuracy: 6075/10000 (61%)
#
# epoch time:  7.86s
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.005062 | ms/batch  1.17
# Train Epoch: 8 [6400/50000 (13%)]	Loss: 0.687684 | ms/batch  7.75
# Train Epoch: 8 [12800/50000 (26%)]	Loss: 0.959304 | ms/batch  7.32
# Train Epoch: 8 [19200/50000 (38%)]	Loss: 1.090489 | ms/batch  7.81
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.931661 | ms/batch  7.78
# Train Epoch: 8 [32000/50000 (64%)]	Loss: 0.833533 | ms/batch  8.10
# Train Epoch: 8 [38400/50000 (77%)]	Loss: 0.892972 | ms/batch  7.62
# Train Epoch: 8 [44800/50000 (90%)]	Loss: 0.850088 | ms/batch  7.69
#
# Train set: Average loss: 0.9535, Accuracy: 33217/50000 (66%)
#
#
# Test set: Average loss: 1.0665, Accuracy: 6212/10000 (62%)
#
# epoch time:  7.54s
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.933116 | ms/batch  1.04
# Train Epoch: 9 [6400/50000 (13%)]	Loss: 0.673301 | ms/batch  7.44
# Train Epoch: 9 [12800/50000 (26%)]	Loss: 1.035422 | ms/batch  7.48
# Train Epoch: 9 [19200/50000 (38%)]	Loss: 1.120073 | ms/batch  7.56
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 0.740365 | ms/batch  7.53
# Train Epoch: 9 [32000/50000 (64%)]	Loss: 0.935179 | ms/batch  7.25
# Train Epoch: 9 [38400/50000 (77%)]	Loss: 0.885292 | ms/batch  7.94
# Train Epoch: 9 [44800/50000 (90%)]	Loss: 0.702708 | ms/batch  7.86
#
# Train set: Average loss: 0.9163, Accuracy: 33888/50000 (68%)
#
#
# Test set: Average loss: 1.0881, Accuracy: 6269/10000 (63%)
#
# epoch time:  7.42s
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.721316 | ms/batch  1.14
# Train Epoch: 10 [6400/50000 (13%)]	Loss: 1.035013 | ms/batch  7.54
# Train Epoch: 10 [12800/50000 (26%)]	Loss: 0.990792 | ms/batch  7.35
# Train Epoch: 10 [19200/50000 (38%)]	Loss: 0.910740 | ms/batch  7.56
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.062713 | ms/batch  7.34
# Train Epoch: 10 [32000/50000 (64%)]	Loss: 0.899390 | ms/batch  7.18
# Train Epoch: 10 [38400/50000 (77%)]	Loss: 0.909267 | ms/batch  7.42
# Train Epoch: 10 [44800/50000 (90%)]	Loss: 0.999160 | ms/batch  7.32
#
# Train set: Average loss: 0.8989, Accuracy: 34141/50000 (68%)
#
#
# Test set: Average loss: 1.1695, Accuracy: 6159/10000 (62%)
#
# epoch time:  7.14s
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.610834 | ms/batch  1.07
# Train Epoch: 11 [6400/50000 (13%)]	Loss: 0.829156 | ms/batch  7.49
# Train Epoch: 11 [12800/50000 (26%)]	Loss: 0.983776 | ms/batch  7.61
# Train Epoch: 11 [19200/50000 (38%)]	Loss: 0.666936 | ms/batch  7.17
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.769700 | ms/batch  7.18
# Train Epoch: 11 [32000/50000 (64%)]	Loss: 1.092435 | ms/batch  7.13
# Train Epoch: 11 [38400/50000 (77%)]	Loss: 0.692256 | ms/batch  7.18
# Train Epoch: 11 [44800/50000 (90%)]	Loss: 1.139056 | ms/batch  7.41
#
# Train set: Average loss: 0.8726, Accuracy: 34669/50000 (69%)
#
#
# Test set: Average loss: 1.1169, Accuracy: 6193/10000 (62%)
#
# epoch time:  7.11s
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.865730 | ms/batch  1.42
# Train Epoch: 12 [6400/50000 (13%)]	Loss: 0.867742 | ms/batch  7.44
# Train Epoch: 12 [12800/50000 (26%)]	Loss: 0.630902 | ms/batch  7.49
# Train Epoch: 12 [19200/50000 (38%)]	Loss: 0.807541 | ms/batch  7.28
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.649880 | ms/batch  7.51
# Train Epoch: 12 [32000/50000 (64%)]	Loss: 0.756887 | ms/batch  7.35
# Train Epoch: 12 [38400/50000 (77%)]	Loss: 0.737176 | ms/batch  7.62
# Train Epoch: 12 [44800/50000 (90%)]	Loss: 0.790212 | ms/batch  7.33
#
# Train set: Average loss: 0.8512, Accuracy: 35071/50000 (70%)
#
#
# Test set: Average loss: 1.1758, Accuracy: 6064/10000 (61%)
#
# epoch time:  7.26s
# Train Epoch: 13 [0/50000 (0%)]	Loss: 1.040334 | ms/batch  1.12
# Train Epoch: 13 [6400/50000 (13%)]	Loss: 1.058172 | ms/batch  7.55
# Train Epoch: 13 [12800/50000 (26%)]	Loss: 0.746705 | ms/batch  7.61
# Train Epoch: 13 [19200/50000 (38%)]	Loss: 0.731260 | ms/batch  7.91
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.792092 | ms/batch  8.96
# Train Epoch: 13 [32000/50000 (64%)]	Loss: 1.071908 | ms/batch  8.03
# Train Epoch: 13 [38400/50000 (77%)]	Loss: 0.822316 | ms/batch  7.94
# Train Epoch: 13 [44800/50000 (90%)]	Loss: 0.747968 | ms/batch  7.79
#
# Train set: Average loss: 0.8401, Accuracy: 35141/50000 (70%)
#
#
# Test set: Average loss: 1.1227, Accuracy: 6240/10000 (62%)
#
# epoch time:  7.72s
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.939854 | ms/batch  1.00
# Train Epoch: 14 [6400/50000 (13%)]	Loss: 0.794024 | ms/batch  8.13
# Train Epoch: 14 [12800/50000 (26%)]	Loss: 0.554531 | ms/batch  7.67
# Train Epoch: 14 [19200/50000 (38%)]	Loss: 0.723664 | ms/batch  7.78
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.858822 | ms/batch  7.84
# Train Epoch: 14 [32000/50000 (64%)]	Loss: 1.089304 | ms/batch  7.34
# Train Epoch: 14 [38400/50000 (77%)]	Loss: 0.971264 | ms/batch  7.56
# Train Epoch: 14 [44800/50000 (90%)]	Loss: 0.825863 | ms/batch  8.03
#
# Train set: Average loss: 0.8224, Accuracy: 35510/50000 (71%)
#
#
# Test set: Average loss: 1.1122, Accuracy: 6205/10000 (62%)
#
# epoch time:  7.48s
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.752131 | ms/batch  1.32
# Train Epoch: 15 [6400/50000 (13%)]	Loss: 0.661735 | ms/batch  8.23
# Train Epoch: 15 [12800/50000 (26%)]	Loss: 0.855413 | ms/batch  7.70
# Train Epoch: 15 [19200/50000 (38%)]	Loss: 0.826623 | ms/batch  7.96
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.959418 | ms/batch  7.36
# Train Epoch: 15 [32000/50000 (64%)]	Loss: 0.874345 | ms/batch  7.75
# Train Epoch: 15 [38400/50000 (77%)]	Loss: 0.748674 | ms/batch  7.49
# Train Epoch: 15 [44800/50000 (90%)]	Loss: 1.119160 | ms/batch  8.15
#
# Train set: Average loss: 0.8106, Accuracy: 35674/50000 (71%)
#
#
# Test set: Average loss: 1.1389, Accuracy: 6174/10000 (62%)
#
# epoch time:  7.56s
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.844305 | ms/batch  1.18
# Train Epoch: 16 [6400/50000 (13%)]	Loss: 0.632227 | ms/batch  7.65
# Train Epoch: 16 [12800/50000 (26%)]	Loss: 0.738980 | ms/batch  7.89
# Train Epoch: 16 [19200/50000 (38%)]	Loss: 0.718919 | ms/batch  7.52
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.818849 | ms/batch  7.59
# Train Epoch: 16 [32000/50000 (64%)]	Loss: 0.901289 | ms/batch  7.53
# Train Epoch: 16 [38400/50000 (77%)]	Loss: 0.954832 | ms/batch  7.46
# Train Epoch: 16 [44800/50000 (90%)]	Loss: 0.749763 | ms/batch  7.93
#
# Train set: Average loss: 0.7947, Accuracy: 35902/50000 (72%)
#
#
# Test set: Average loss: 1.1781, Accuracy: 6095/10000 (61%)
#
# epoch time:  7.49s
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.894217 | ms/batch  1.23
# Train Epoch: 17 [6400/50000 (13%)]	Loss: 0.625595 | ms/batch  7.87
# Train Epoch: 17 [12800/50000 (26%)]	Loss: 0.935533 | ms/batch  7.72
# Train Epoch: 17 [19200/50000 (38%)]	Loss: 0.814892 | ms/batch  7.23
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.749906 | ms/batch  7.67
# Train Epoch: 17 [32000/50000 (64%)]	Loss: 0.617235 | ms/batch  8.09
# Train Epoch: 17 [38400/50000 (77%)]	Loss: 0.626028 | ms/batch  7.24
# Train Epoch: 17 [44800/50000 (90%)]	Loss: 1.142736 | ms/batch  7.32
#
# Train set: Average loss: 0.7816, Accuracy: 36155/50000 (72%)
#
#
# Test set: Average loss: 1.2101, Accuracy: 6148/10000 (61%)
#
# epoch time:  7.33s
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.965392 | ms/batch  1.10
# Train Epoch: 18 [6400/50000 (13%)]	Loss: 0.835242 | ms/batch  7.35
# Train Epoch: 18 [12800/50000 (26%)]	Loss: 0.833669 | ms/batch  7.82
# Train Epoch: 18 [19200/50000 (38%)]	Loss: 0.819658 | ms/batch  7.23
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.883061 | ms/batch  7.88
# Train Epoch: 18 [32000/50000 (64%)]	Loss: 0.941070 | ms/batch  7.64
# Train Epoch: 18 [38400/50000 (77%)]	Loss: 0.892059 | ms/batch  7.45
# Train Epoch: 18 [44800/50000 (90%)]	Loss: 0.930016 | ms/batch  7.97
#
# Train set: Average loss: 0.7746, Accuracy: 36293/50000 (73%)
#
#
# Test set: Average loss: 1.2003, Accuracy: 6136/10000 (61%)
#
# epoch time:  7.36s
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.746303 | ms/batch  1.00
# Train Epoch: 19 [6400/50000 (13%)]	Loss: 0.619444 | ms/batch  7.26
# Train Epoch: 19 [12800/50000 (26%)]	Loss: 0.709804 | ms/batch  7.26
# Train Epoch: 19 [19200/50000 (38%)]	Loss: 0.672346 | ms/batch  7.52
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.731034 | ms/batch  7.94
# Train Epoch: 19 [32000/50000 (64%)]	Loss: 0.684359 | ms/batch  7.22
# Train Epoch: 19 [38400/50000 (77%)]	Loss: 0.778672 | ms/batch  7.41
# Train Epoch: 19 [44800/50000 (90%)]	Loss: 0.906456 | ms/batch  7.55
#
# Train set: Average loss: 0.7723, Accuracy: 36258/50000 (73%)
#
#
# Test set: Average loss: 1.1822, Accuracy: 6219/10000 (62%)
#
# epoch time:  7.23s
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.690872 | ms/batch  1.15
# Train Epoch: 20 [6400/50000 (13%)]	Loss: 0.611439 | ms/batch  7.27
# Train Epoch: 20 [12800/50000 (26%)]	Loss: 0.830789 | ms/batch  7.79
# Train Epoch: 20 [19200/50000 (38%)]	Loss: 0.861837 | ms/batch  7.83
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.850065 | ms/batch  7.49
# Train Epoch: 20 [32000/50000 (64%)]	Loss: 0.945726 | ms/batch  8.37
# Train Epoch: 20 [38400/50000 (77%)]	Loss: 0.713757 | ms/batch  8.53
# Train Epoch: 20 [44800/50000 (90%)]	Loss: 0.591259 | ms/batch  7.64
#
# Train set: Average loss: 0.7545, Accuracy: 36541/50000 (73%)
#
#
# Test set: Average loss: 1.1457, Accuracy: 6347/10000 (63%)
#
# epoch time:  7.51s
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.404863 | ms/batch  1.08
# Train Epoch: 21 [6400/50000 (13%)]	Loss: 0.472378 | ms/batch  7.91
# Train Epoch: 21 [12800/50000 (26%)]	Loss: 0.569186 | ms/batch  7.66
# Train Epoch: 21 [19200/50000 (38%)]	Loss: 0.613507 | ms/batch  7.67
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.586565 | ms/batch  8.11
# Train Epoch: 21 [32000/50000 (64%)]	Loss: 0.704509 | ms/batch  7.96
# Train Epoch: 21 [38400/50000 (77%)]	Loss: 0.554463 | ms/batch  7.61
# Train Epoch: 21 [44800/50000 (90%)]	Loss: 0.560948 | ms/batch  7.41
#
# Train set: Average loss: 0.5852, Accuracy: 39724/50000 (79%)
#
#
# Test set: Average loss: 1.1262, Accuracy: 6494/10000 (65%)
#
# epoch time:  7.48s
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.497101 | ms/batch  1.11
# Train Epoch: 22 [6400/50000 (13%)]	Loss: 0.669377 | ms/batch  7.45
# Train Epoch: 22 [12800/50000 (26%)]	Loss: 0.593173 | ms/batch  7.76
# Train Epoch: 22 [19200/50000 (38%)]	Loss: 0.458033 | ms/batch  7.29
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.472863 | ms/batch  7.81
# Train Epoch: 22 [32000/50000 (64%)]	Loss: 0.604330 | ms/batch  7.96
# Train Epoch: 22 [38400/50000 (77%)]	Loss: 0.438199 | ms/batch  7.59
# Train Epoch: 22 [44800/50000 (90%)]	Loss: 0.478185 | ms/batch  8.04
#
# Train set: Average loss: 0.5528, Accuracy: 40306/50000 (81%)
#
#
# Test set: Average loss: 1.1415, Accuracy: 6492/10000 (65%)
#
# epoch time:  7.51s
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.547740 | ms/batch  1.11
# Train Epoch: 23 [6400/50000 (13%)]	Loss: 0.512136 | ms/batch  7.56
# Train Epoch: 23 [12800/50000 (26%)]	Loss: 0.582977 | ms/batch  7.42
# Train Epoch: 23 [19200/50000 (38%)]	Loss: 0.534205 | ms/batch  7.87
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.479857 | ms/batch  7.65
# Train Epoch: 23 [32000/50000 (64%)]	Loss: 0.515430 | ms/batch  7.38
# Train Epoch: 23 [38400/50000 (77%)]	Loss: 0.507717 | ms/batch  8.44
# Train Epoch: 23 [44800/50000 (90%)]	Loss: 0.611598 | ms/batch  7.79
#
# Train set: Average loss: 0.5404, Accuracy: 40580/50000 (81%)
#
#
# Test set: Average loss: 1.1547, Accuracy: 6477/10000 (65%)
#
# epoch time:  7.46s
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.526122 | ms/batch  1.29
# Train Epoch: 24 [6400/50000 (13%)]	Loss: 0.681361 | ms/batch  7.89
# Train Epoch: 24 [12800/50000 (26%)]	Loss: 0.481876 | ms/batch  8.03
# Train Epoch: 24 [19200/50000 (38%)]	Loss: 0.431601 | ms/batch  7.77
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.576301 | ms/batch  7.38
# Train Epoch: 24 [32000/50000 (64%)]	Loss: 0.432291 | ms/batch  7.92
# Train Epoch: 24 [38400/50000 (77%)]	Loss: 0.459538 | ms/batch  8.01
# Train Epoch: 24 [44800/50000 (90%)]	Loss: 0.673244 | ms/batch  8.00
#
# Train set: Average loss: 0.5321, Accuracy: 40630/50000 (81%)
#
#
# Test set: Average loss: 1.1553, Accuracy: 6459/10000 (65%)
#
# epoch time:  7.63s
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.539404 | ms/batch  1.18
# Train Epoch: 25 [6400/50000 (13%)]	Loss: 0.490459 | ms/batch  7.92
# Train Epoch: 25 [12800/50000 (26%)]	Loss: 0.366668 | ms/batch  8.08
# Train Epoch: 25 [19200/50000 (38%)]	Loss: 0.404689 | ms/batch  7.91
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.406090 | ms/batch  7.91
# Train Epoch: 25 [32000/50000 (64%)]	Loss: 0.519757 | ms/batch  7.41
# Train Epoch: 25 [38400/50000 (77%)]	Loss: 0.524929 | ms/batch  7.71
# Train Epoch: 25 [44800/50000 (90%)]	Loss: 0.648136 | ms/batch  8.21
#
# Train set: Average loss: 0.5252, Accuracy: 40791/50000 (82%)
#
#
# Test set: Average loss: 1.1692, Accuracy: 6460/10000 (65%)
#
# epoch time:  7.66s
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.802263 | ms/batch  1.13
# Train Epoch: 26 [6400/50000 (13%)]	Loss: 0.410055 | ms/batch  7.25
# Train Epoch: 26 [12800/50000 (26%)]	Loss: 0.445229 | ms/batch  7.99
# Train Epoch: 26 [19200/50000 (38%)]	Loss: 0.583941 | ms/batch  7.75
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.532221 | ms/batch  7.66
# Train Epoch: 26 [32000/50000 (64%)]	Loss: 0.592594 | ms/batch  7.90
# Train Epoch: 26 [38400/50000 (77%)]	Loss: 0.496082 | ms/batch  7.78
# Train Epoch: 26 [44800/50000 (90%)]	Loss: 0.388190 | ms/batch  7.57
#
# Train set: Average loss: 0.5192, Accuracy: 40981/50000 (82%)
#
#
# Test set: Average loss: 1.1801, Accuracy: 6462/10000 (65%)
#
# epoch time:  7.42s
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.582315 | ms/batch  1.01
# Train Epoch: 27 [6400/50000 (13%)]	Loss: 0.434320 | ms/batch  7.83
# Train Epoch: 27 [12800/50000 (26%)]	Loss: 0.525151 | ms/batch  7.50
# Train Epoch: 27 [19200/50000 (38%)]	Loss: 0.644224 | ms/batch  7.25
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.457624 | ms/batch  7.29
# Train Epoch: 27 [32000/50000 (64%)]	Loss: 0.508191 | ms/batch  7.11
# Train Epoch: 27 [38400/50000 (77%)]	Loss: 0.449688 | ms/batch  8.10
# Train Epoch: 27 [44800/50000 (90%)]	Loss: 0.693893 | ms/batch  8.67
#
# Train set: Average loss: 0.5137, Accuracy: 41037/50000 (82%)
#
#
# Test set: Average loss: 1.1880, Accuracy: 6471/10000 (65%)
#
# epoch time:  7.38s
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.555899 | ms/batch  1.13
# Train Epoch: 28 [6400/50000 (13%)]	Loss: 0.506316 | ms/batch  7.28
# Train Epoch: 28 [12800/50000 (26%)]	Loss: 0.271384 | ms/batch  8.18
# Train Epoch: 28 [19200/50000 (38%)]	Loss: 0.566854 | ms/batch  7.63
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.544748 | ms/batch  7.70
# Train Epoch: 28 [32000/50000 (64%)]	Loss: 0.631112 | ms/batch  7.68
# Train Epoch: 28 [38400/50000 (77%)]	Loss: 0.478732 | ms/batch  7.55
# Train Epoch: 28 [44800/50000 (90%)]	Loss: 0.371996 | ms/batch  7.34
#
# Train set: Average loss: 0.5100, Accuracy: 41051/50000 (82%)
#
#
# Test set: Average loss: 1.2087, Accuracy: 6457/10000 (65%)
#
# epoch time:  7.34s
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.366064 | ms/batch  1.04
# Train Epoch: 29 [6400/50000 (13%)]	Loss: 0.782073 | ms/batch  7.80
# Train Epoch: 29 [12800/50000 (26%)]	Loss: 0.405132 | ms/batch  7.50
# Train Epoch: 29 [19200/50000 (38%)]	Loss: 0.400659 | ms/batch  7.25
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.632052 | ms/batch  7.65
# Train Epoch: 29 [32000/50000 (64%)]	Loss: 0.369320 | ms/batch  7.59
# Train Epoch: 29 [38400/50000 (77%)]	Loss: 0.478849 | ms/batch  7.76
# Train Epoch: 29 [44800/50000 (90%)]	Loss: 0.565010 | ms/batch  8.26
#
# Train set: Average loss: 0.5042, Accuracy: 41162/50000 (82%)
#
#
# Test set: Average loss: 1.2116, Accuracy: 6390/10000 (64%)
#
# epoch time:  7.40s
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.400487 | ms/batch  1.01
# Train Epoch: 30 [6400/50000 (13%)]	Loss: 0.463159 | ms/batch  7.34
# Train Epoch: 30 [12800/50000 (26%)]	Loss: 0.672437 | ms/batch  7.95
# Train Epoch: 30 [19200/50000 (38%)]	Loss: 0.531664 | ms/batch  7.64
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.462129 | ms/batch  7.54
# Train Epoch: 30 [32000/50000 (64%)]	Loss: 0.421442 | ms/batch  8.53
# Train Epoch: 30 [38400/50000 (77%)]	Loss: 0.523549 | ms/batch  7.19
# Train Epoch: 30 [44800/50000 (90%)]	Loss: 0.499123 | ms/batch  7.64
#
# Train set: Average loss: 0.5001, Accuracy: 41261/50000 (83%)
#
#
# Test set: Average loss: 1.2167, Accuracy: 6442/10000 (64%)
#
# epoch time:  7.54s
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.382246 | ms/batch  1.38
# Train Epoch: 31 [6400/50000 (13%)]	Loss: 0.580645 | ms/batch  7.60
# Train Epoch: 31 [12800/50000 (26%)]	Loss: 0.462570 | ms/batch  7.27
# Train Epoch: 31 [19200/50000 (38%)]	Loss: 0.516658 | ms/batch  7.69
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.390717 | ms/batch  7.54
# Train Epoch: 31 [32000/50000 (64%)]	Loss: 0.368477 | ms/batch  7.72
# Train Epoch: 31 [38400/50000 (77%)]	Loss: 0.749213 | ms/batch  7.47
# Train Epoch: 31 [44800/50000 (90%)]	Loss: 0.502901 | ms/batch  7.39
#
# Train set: Average loss: 0.4954, Accuracy: 41363/50000 (83%)
#
#
# Test set: Average loss: 1.2315, Accuracy: 6416/10000 (64%)
#
# epoch time:  7.34s
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.535858 | ms/batch  1.16
# Train Epoch: 32 [6400/50000 (13%)]	Loss: 0.600995 | ms/batch  7.23
# Train Epoch: 32 [12800/50000 (26%)]	Loss: 0.520744 | ms/batch  7.46
# Train Epoch: 32 [19200/50000 (38%)]	Loss: 0.648029 | ms/batch  7.29
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.332862 | ms/batch  7.43
# Train Epoch: 32 [32000/50000 (64%)]	Loss: 0.667068 | ms/batch  8.18
# Train Epoch: 32 [38400/50000 (77%)]	Loss: 0.370546 | ms/batch  8.67
# Train Epoch: 32 [44800/50000 (90%)]	Loss: 0.619051 | ms/batch  7.61
#
# Train set: Average loss: 0.4928, Accuracy: 41371/50000 (83%)
#
#
# Test set: Average loss: 1.2365, Accuracy: 6423/10000 (64%)
#
# epoch time:  7.55s
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.511285 | ms/batch  1.10
# Train Epoch: 33 [6400/50000 (13%)]	Loss: 0.473300 | ms/batch  8.34
# Train Epoch: 33 [12800/50000 (26%)]	Loss: 0.444164 | ms/batch  7.51
# Train Epoch: 33 [19200/50000 (38%)]	Loss: 0.632225 | ms/batch  8.15
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.548162 | ms/batch  8.31
# Train Epoch: 33 [32000/50000 (64%)]	Loss: 0.443410 | ms/batch  8.01
# Train Epoch: 33 [38400/50000 (77%)]	Loss: 0.494858 | ms/batch  8.13
# Train Epoch: 33 [44800/50000 (90%)]	Loss: 0.481921 | ms/batch  7.47
#
# Train set: Average loss: 0.4885, Accuracy: 41477/50000 (83%)
#
#
# Test set: Average loss: 1.2454, Accuracy: 6410/10000 (64%)
#
# epoch time:  7.69s
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.368515 | ms/batch  1.02
# Train Epoch: 34 [6400/50000 (13%)]	Loss: 0.416165 | ms/batch  8.32
# Train Epoch: 34 [12800/50000 (26%)]	Loss: 0.357782 | ms/batch  8.15
# Train Epoch: 34 [19200/50000 (38%)]	Loss: 0.507038 | ms/batch  7.59
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.548609 | ms/batch  7.98
# Train Epoch: 34 [32000/50000 (64%)]	Loss: 0.402341 | ms/batch  7.65
# Train Epoch: 34 [38400/50000 (77%)]	Loss: 0.681177 | ms/batch  7.84
# Train Epoch: 34 [44800/50000 (90%)]	Loss: 0.468647 | ms/batch  8.65
#
# Train set: Average loss: 0.4854, Accuracy: 41519/50000 (83%)
#
#
# Test set: Average loss: 1.2564, Accuracy: 6409/10000 (64%)
#
# epoch time:  7.69s
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.685963 | ms/batch  1.02
# Train Epoch: 35 [6400/50000 (13%)]	Loss: 0.458545 | ms/batch  7.42
# Train Epoch: 35 [12800/50000 (26%)]	Loss: 0.323144 | ms/batch  7.79
# Train Epoch: 35 [19200/50000 (38%)]	Loss: 0.492425 | ms/batch  8.33
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.445915 | ms/batch  7.76
# Train Epoch: 35 [32000/50000 (64%)]	Loss: 0.494335 | ms/batch  8.65
# Train Epoch: 35 [38400/50000 (77%)]	Loss: 0.463560 | ms/batch  7.19
# Train Epoch: 35 [44800/50000 (90%)]	Loss: 0.515442 | ms/batch  7.57
#
# Train set: Average loss: 0.4817, Accuracy: 41623/50000 (83%)
#
#
# Test set: Average loss: 1.2755, Accuracy: 6382/10000 (64%)
#
# epoch time:  7.53s
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.273932 | ms/batch  1.01
# Train Epoch: 36 [6400/50000 (13%)]	Loss: 0.371510 | ms/batch  7.71
# Train Epoch: 36 [12800/50000 (26%)]	Loss: 0.323532 | ms/batch  8.32
# Train Epoch: 36 [19200/50000 (38%)]	Loss: 0.388454 | ms/batch  7.62
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.411386 | ms/batch  7.34
# Train Epoch: 36 [32000/50000 (64%)]	Loss: 0.502558 | ms/batch  7.44
# Train Epoch: 36 [38400/50000 (77%)]	Loss: 0.518058 | ms/batch  7.78
# Train Epoch: 36 [44800/50000 (90%)]	Loss: 0.447566 | ms/batch  7.42
#
# Train set: Average loss: 0.4771, Accuracy: 41652/50000 (83%)
#
#
# Test set: Average loss: 1.2820, Accuracy: 6393/10000 (64%)
#
# epoch time:  7.44s
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.587759 | ms/batch  1.00
# Train Epoch: 37 [6400/50000 (13%)]	Loss: 0.351788 | ms/batch  7.82
# Train Epoch: 37 [12800/50000 (26%)]	Loss: 0.483884 | ms/batch  7.21
# Train Epoch: 37 [19200/50000 (38%)]	Loss: 0.510042 | ms/batch  7.82
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.410110 | ms/batch  7.47
# Train Epoch: 37 [32000/50000 (64%)]	Loss: 0.485166 | ms/batch  8.08
# Train Epoch: 37 [38400/50000 (77%)]	Loss: 0.426507 | ms/batch  8.11
# Train Epoch: 37 [44800/50000 (90%)]	Loss: 0.636556 | ms/batch  7.45
#
# Train set: Average loss: 0.4740, Accuracy: 41706/50000 (83%)
#
#
# Test set: Average loss: 1.2856, Accuracy: 6402/10000 (64%)
#
# epoch time:  7.56s
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.440443 | ms/batch  1.01
# Train Epoch: 38 [6400/50000 (13%)]	Loss: 0.448846 | ms/batch  7.64
# Train Epoch: 38 [12800/50000 (26%)]	Loss: 0.460948 | ms/batch  7.74
# Train Epoch: 38 [19200/50000 (38%)]	Loss: 0.458734 | ms/batch  7.71
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.397357 | ms/batch  7.92
# Train Epoch: 38 [32000/50000 (64%)]	Loss: 0.566936 | ms/batch  7.89
# Train Epoch: 38 [38400/50000 (77%)]	Loss: 0.438742 | ms/batch  7.80
# Train Epoch: 38 [44800/50000 (90%)]	Loss: 0.622630 | ms/batch  8.37
#
# Train set: Average loss: 0.4708, Accuracy: 41792/50000 (84%)
#
#
# Test set: Average loss: 1.2964, Accuracy: 6380/10000 (64%)
#
# epoch time:  7.57s
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.492915 | ms/batch  1.04
# Train Epoch: 39 [6400/50000 (13%)]	Loss: 0.494528 | ms/batch  7.82
# Train Epoch: 39 [12800/50000 (26%)]	Loss: 0.432105 | ms/batch  7.84
# Train Epoch: 39 [19200/50000 (38%)]	Loss: 0.444157 | ms/batch  8.12
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.451402 | ms/batch  9.01
# Train Epoch: 39 [32000/50000 (64%)]	Loss: 0.428291 | ms/batch  7.60
# Train Epoch: 39 [38400/50000 (77%)]	Loss: 0.518718 | ms/batch  8.49
# Train Epoch: 39 [44800/50000 (90%)]	Loss: 0.436844 | ms/batch  7.67
#
# Train set: Average loss: 0.4680, Accuracy: 41836/50000 (84%)
#
#
# Test set: Average loss: 1.3069, Accuracy: 6355/10000 (64%)
#
# epoch time:  7.71s
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.766041 | ms/batch  1.12
# Train Epoch: 40 [6400/50000 (13%)]	Loss: 0.577771 | ms/batch  7.99
# Train Epoch: 40 [12800/50000 (26%)]	Loss: 0.754580 | ms/batch  8.22
# Train Epoch: 40 [19200/50000 (38%)]	Loss: 0.329799 | ms/batch  7.35
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.407854 | ms/batch  7.58
# Train Epoch: 40 [32000/50000 (64%)]	Loss: 0.436995 | ms/batch  7.72
# Train Epoch: 40 [38400/50000 (77%)]	Loss: 0.475889 | ms/batch  7.29
# Train Epoch: 40 [44800/50000 (90%)]	Loss: 0.539208 | ms/batch  7.33
#
# Train set: Average loss: 0.4642, Accuracy: 41837/50000 (84%)
#
#
# Test set: Average loss: 1.3107, Accuracy: 6357/10000 (64%)
#
# epoch time:  7.36s
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.422888 | ms/batch  1.01
# Train Epoch: 41 [6400/50000 (13%)]	Loss: 0.409510 | ms/batch  7.83
# Train Epoch: 41 [12800/50000 (26%)]	Loss: 0.397696 | ms/batch  8.10
# Train Epoch: 41 [19200/50000 (38%)]	Loss: 0.362428 | ms/batch  7.52
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.528004 | ms/batch  7.51
# Train Epoch: 41 [32000/50000 (64%)]	Loss: 0.384423 | ms/batch  8.59
# Train Epoch: 41 [38400/50000 (77%)]	Loss: 0.340998 | ms/batch  7.80
# Train Epoch: 41 [44800/50000 (90%)]	Loss: 0.388620 | ms/batch  7.89
#
# Train set: Average loss: 0.4395, Accuracy: 42470/50000 (85%)
#
#
# Test set: Average loss: 1.3146, Accuracy: 6389/10000 (64%)
#
# epoch time:  7.56s
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.615681 | ms/batch  1.23
# Train Epoch: 42 [6400/50000 (13%)]	Loss: 0.314392 | ms/batch  7.53
# Train Epoch: 42 [12800/50000 (26%)]	Loss: 0.389036 | ms/batch  7.61
# Train Epoch: 42 [19200/50000 (38%)]	Loss: 0.570420 | ms/batch  7.59
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.341418 | ms/batch  7.67
# Train Epoch: 42 [32000/50000 (64%)]	Loss: 0.418801 | ms/batch  7.84
# Train Epoch: 42 [38400/50000 (77%)]	Loss: 0.581456 | ms/batch  7.53
# Train Epoch: 42 [44800/50000 (90%)]	Loss: 0.565218 | ms/batch  7.85
#
# Train set: Average loss: 0.4372, Accuracy: 42488/50000 (85%)
#
#
# Test set: Average loss: 1.3195, Accuracy: 6378/10000 (64%)
#
# epoch time:  7.50s
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.454165 | ms/batch  1.15
# Train Epoch: 43 [6400/50000 (13%)]	Loss: 0.563706 | ms/batch  7.55
# Train Epoch: 43 [12800/50000 (26%)]	Loss: 0.417251 | ms/batch  7.75
# Train Epoch: 43 [19200/50000 (38%)]	Loss: 0.577699 | ms/batch  8.07
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.466257 | ms/batch  7.40
# Train Epoch: 43 [32000/50000 (64%)]	Loss: 0.509245 | ms/batch  7.39
# Train Epoch: 43 [38400/50000 (77%)]	Loss: 0.454035 | ms/batch  7.80
# Train Epoch: 43 [44800/50000 (90%)]	Loss: 0.480675 | ms/batch  7.78
#
# Train set: Average loss: 0.4365, Accuracy: 42514/50000 (85%)
#
#
# Test set: Average loss: 1.3204, Accuracy: 6367/10000 (64%)
#
# epoch time:  7.49s
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.386342 | ms/batch  0.98
# Train Epoch: 44 [6400/50000 (13%)]	Loss: 0.497080 | ms/batch  7.89
# Train Epoch: 44 [12800/50000 (26%)]	Loss: 0.463087 | ms/batch  7.87
# Train Epoch: 44 [19200/50000 (38%)]	Loss: 0.669382 | ms/batch  7.69
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.418957 | ms/batch  8.69
# Train Epoch: 44 [32000/50000 (64%)]	Loss: 0.520486 | ms/batch  7.66
# Train Epoch: 44 [38400/50000 (77%)]	Loss: 0.285486 | ms/batch  7.52
# Train Epoch: 44 [44800/50000 (90%)]	Loss: 0.462424 | ms/batch  8.59
#
# Train set: Average loss: 0.4359, Accuracy: 42524/50000 (85%)
#
#
# Test set: Average loss: 1.3238, Accuracy: 6373/10000 (64%)
#
# epoch time:  7.55s
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.518448 | ms/batch  1.00
# Train Epoch: 45 [6400/50000 (13%)]	Loss: 0.287170 | ms/batch  7.40
# Train Epoch: 45 [12800/50000 (26%)]	Loss: 0.512768 | ms/batch  7.34
# Train Epoch: 45 [19200/50000 (38%)]	Loss: 0.309901 | ms/batch  7.16
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.485790 | ms/batch  8.26
# Train Epoch: 45 [32000/50000 (64%)]	Loss: 0.477848 | ms/batch  7.63
# Train Epoch: 45 [38400/50000 (77%)]	Loss: 0.217395 | ms/batch  7.83
# Train Epoch: 45 [44800/50000 (90%)]	Loss: 0.418624 | ms/batch  8.01
#
# Train set: Average loss: 0.4355, Accuracy: 42543/50000 (85%)
#
#
# Test set: Average loss: 1.3247, Accuracy: 6371/10000 (64%)
#
# epoch time:  7.38s
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.530476 | ms/batch  1.10
# Train Epoch: 46 [6400/50000 (13%)]	Loss: 0.367375 | ms/batch  7.46
# Train Epoch: 46 [12800/50000 (26%)]	Loss: 0.408993 | ms/batch  7.87
# Train Epoch: 46 [19200/50000 (38%)]	Loss: 0.408139 | ms/batch  7.81
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.289755 | ms/batch  8.07
# Train Epoch: 46 [32000/50000 (64%)]	Loss: 0.332862 | ms/batch  7.68
# Train Epoch: 46 [38400/50000 (77%)]	Loss: 0.424418 | ms/batch  7.43
# Train Epoch: 46 [44800/50000 (90%)]	Loss: 0.493798 | ms/batch  8.12
#
# Train set: Average loss: 0.4349, Accuracy: 42541/50000 (85%)
#
#
# Test set: Average loss: 1.3265, Accuracy: 6365/10000 (64%)
#
# epoch time:  7.51s
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.325492 | ms/batch  1.25
# Train Epoch: 47 [6400/50000 (13%)]	Loss: 0.293492 | ms/batch  8.60
# Train Epoch: 47 [12800/50000 (26%)]	Loss: 0.365396 | ms/batch  7.88
# Train Epoch: 47 [19200/50000 (38%)]	Loss: 0.459949 | ms/batch  8.39
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.368034 | ms/batch  7.93
# Train Epoch: 47 [32000/50000 (64%)]	Loss: 0.479490 | ms/batch  8.41
# Train Epoch: 47 [38400/50000 (77%)]	Loss: 0.270175 | ms/batch  7.70
# Train Epoch: 47 [44800/50000 (90%)]	Loss: 0.353986 | ms/batch  8.16
#
# Train set: Average loss: 0.4345, Accuracy: 42534/50000 (85%)
#
#
# Test set: Average loss: 1.3268, Accuracy: 6362/10000 (64%)
#
# epoch time:  7.78s
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.219706 | ms/batch  1.40
# Train Epoch: 48 [6400/50000 (13%)]	Loss: 0.404616 | ms/batch  7.96
# Train Epoch: 48 [12800/50000 (26%)]	Loss: 0.381178 | ms/batch  8.11
# Train Epoch: 48 [19200/50000 (38%)]	Loss: 0.304511 | ms/batch  7.97
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.374704 | ms/batch  8.04
# Train Epoch: 48 [32000/50000 (64%)]	Loss: 0.427559 | ms/batch  7.96
# Train Epoch: 48 [38400/50000 (77%)]	Loss: 0.431447 | ms/batch  7.40
# Train Epoch: 48 [44800/50000 (90%)]	Loss: 0.590680 | ms/batch  8.32
#
# Train set: Average loss: 0.4340, Accuracy: 42580/50000 (85%)
#
#
# Test set: Average loss: 1.3290, Accuracy: 6368/10000 (64%)
#
# epoch time:  7.80s
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.383271 | ms/batch  1.48
# Train Epoch: 49 [6400/50000 (13%)]	Loss: 0.549541 | ms/batch  7.80
# Train Epoch: 49 [12800/50000 (26%)]	Loss: 0.337385 | ms/batch  8.31
# Train Epoch: 49 [19200/50000 (38%)]	Loss: 0.257059 | ms/batch  7.85
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.461350 | ms/batch  8.24
# Train Epoch: 49 [32000/50000 (64%)]	Loss: 0.286468 | ms/batch  8.14
# Train Epoch: 49 [38400/50000 (77%)]	Loss: 0.227646 | ms/batch  8.06
# Train Epoch: 49 [44800/50000 (90%)]	Loss: 0.319526 | ms/batch  8.33
#
# Train set: Average loss: 0.4336, Accuracy: 42527/50000 (85%)
#
#
# Test set: Average loss: 1.3305, Accuracy: 6364/10000 (64%)
#
# epoch time:  7.91s
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.480926 | ms/batch  1.27
# Train Epoch: 50 [6400/50000 (13%)]	Loss: 0.393291 | ms/batch  7.56
# Train Epoch: 50 [12800/50000 (26%)]	Loss: 0.307897 | ms/batch  7.93
# Train Epoch: 50 [19200/50000 (38%)]	Loss: 0.465551 | ms/batch  8.10
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.409166 | ms/batch  7.75
# Train Epoch: 50 [32000/50000 (64%)]	Loss: 0.484108 | ms/batch  7.76
# Train Epoch: 50 [38400/50000 (77%)]	Loss: 0.484295 | ms/batch  7.68
# Train Epoch: 50 [44800/50000 (90%)]	Loss: 0.643206 | ms/batch  7.81
#
# Train set: Average loss: 0.4333, Accuracy: 42565/50000 (85%)
#
#
# Test set: Average loss: 1.3341, Accuracy: 6354/10000 (64%)
#
# epoch time:  7.67s

# %%
logdf = pd.DataFrame(logs)

# %%
best_loss_epoch, best_loss = logdf.sort_values(by='valid_loss')[['epoch', 'valid_loss']].to_numpy()[0]
best_acc_epoch, best_acc = logdf.sort_values(by='valid_acc', ascending=False)[['epoch', 'valid_acc']].to_numpy()[0]
print(f'Best validation loss is {best_loss:.4f}, achieved at epoch {int(best_loss_epoch)}.\n'
      f'But best validation accuracy is {best_acc}, achieved much later at epoch {int(best_acc_epoch)}.')
# Out:
# Best validation loss is 1.0665, achieved at epoch 8.
# But best validation accuracy is 0.6494, achieved much later at epoch 21.

# %%
def tight_layout(fig):
    fig.tight_layout(rect=[0, 0.03, 1, 0.95])

# %%
plt.figure(figsize=(8, 7))
plt.subplot(221)
sns.lineplot(data=logdf, x='epoch', y='valid_loss')
plt.axvline(best_loss_epoch, c='orange')
plt.annotate(f'validation loss\nincreases after\nepoch {int(best_loss_epoch)},\nindicating\n"overfitting"',
            xy=(best_loss_epoch, best_loss),  xycoords='data',
            xytext=(15, 1.25), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='bottom',
             wrap=True
            )
plt.subplot(222)
sns.lineplot(data=logdf, x='epoch', y='valid_acc')
plt.axvline(best_loss_epoch, c='orange')
plt.axvline(best_acc_epoch, c='violet')
plt.text(25, 0.5,
         f'...but\nvalidation\naccuracy\noverfitting\noccurs much\nlater on\nepoch {int(best_acc_epoch)}!',
         horizontalalignment='left', verticalalignment='bottom')

plt.subplot(223)
sns.lineplot(data=logdf, x='epoch', y='train_loss')
plt.axvline(best_loss_epoch, c='orange')
plt.annotate(f'validation loss\nincreases after\nepoch {int(best_loss_epoch)}',
            xy=(best_loss_epoch, best_loss),  xycoords='data',
            xytext=(15, 1.2), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             wrap=True
            )
plt.subplot(224)
sns.lineplot(data=logdf, x='epoch', y='train_acc')
plt.axvline(best_loss_epoch, c='orange')
max_train_acc = logdf.train_acc.max()
plt.axhline(max_train_acc, c='pink')
plt.annotate(f'max train\naccuracy is\n{100*max_train_acc:.1f}%',
            xy=(25, max_train_acc),  xycoords='data',
            xytext=(15, 0.5), textcoords='data',
            arrowprops=dict(facecolor='black', shrink=0.05),
            horizontalalignment='left', verticalalignment='top',
             wrap=True
            )
plt.suptitle('Underparametrized LeNet validation loss is still not a good early stopping indicator')
tight_layout(plt)
plt.savefig('lenet-small.png', dpi=200, bbox_inches='tight')
